# %% [markdown]
# <a href="https://colab.research.google.com/github/k-avya/LINEAR-REGRESSION/blob/main/LINEAR_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SIMPLE LINEAR REGRESSION**

# %%
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
# %matplotlib inline
from mlxtend.plotting import plot_linear_regression
import seaborn as sns

# %% [markdown]
# **IMPORTING THE DATASET**

# %%
url = "http://bit.ly/w-data"
s_data = pd.read_csv(url)
print("Data imported successfully")

s_data.head(25)
# Out:
# Data imported successfully
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
x = np.array(s_data['Hours']).reshape((-1, 1))
y = np.array(s_data['Scores'])
print(x)
print(y)
# Out:
# [[2.5]
#  [5.1]
#  [3.2]
#  [8.5]
#  [3.5]
#  [1.5]
#  [9.2]
#  [5.5]
#  [8.3]
#  [2.7]
#  [7.7]
#  [5.9]
#  [4.5]
#  [3.3]
#  [1.1]
#  [8.9]
#  [2.5]
#  [1.9]
#  [6.1]
#  [7.4]
#  [2.7]
#  [4.8]
#  [3.8]
#  [6.9]
#  [7.8]]
# [21 47 27 75 30 20 88 60 81 25 85 62 41 42 17 95 30 24 67 69 30 54 35 76
#  86]

# %% [markdown]
# **CREATE A MODEL AND FIT IT**

# %%
model = LinearRegression()
model.fit(x, y)
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.9529481969048356

# %%
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# intercept: 2.48367340537321
# slope: [9.77580339]

# %%
new_model = LinearRegression().fit(x, y.reshape((-1, 1)))
print('intercept:', new_model.intercept_)
print('slope:', new_model.coef_)
# Out:
# intercept: [2.48367341]
# slope: [[9.77580339]]

# %% [markdown]
# **PREDICTING THE RESPONSE**

# %%
y_pred = model.predict(x)
print('predicted response:', y_pred, sep='\n')
# Out:
# predicted response:
# [26.92318188 52.3402707  33.76624426 85.57800223 36.69898527 17.14737849
#  92.4210646  56.25059205 83.62284155 28.87834256 77.75735951 60.16091341
#  46.47478866 34.74382459 13.23705714 89.48832358 26.92318188 21.05769985
#  62.11607409 74.8246185  28.87834256 49.40752968 39.63172629 69.9367168
#  78.73493985]

# %%
y_pred = model.intercept_ + model.coef_ * x
print('predicted response:', y_pred, sep='\n')
# Out:
# predicted response:
# [[26.92318188]
#  [52.3402707 ]
#  [33.76624426]
#  [85.57800223]
#  [36.69898527]
#  [17.14737849]
#  [92.4210646 ]
#  [56.25059205]
#  [83.62284155]
#  [28.87834256]
#  [77.75735951]
#  [60.16091341]
#  [46.47478866]
#  [34.74382459]
#  [13.23705714]
#  [89.48832358]
#  [26.92318188]
#  [21.05769985]
#  [62.11607409]
#  [74.8246185 ]
#  [28.87834256]
#  [49.40752968]
#  [39.63172629]
#  [69.9367168 ]
#  [78.73493985]]

# %%
x_new = np.arange(5).reshape((-1, 1))
print(x_new)
y_new = model.predict(x_new)
print(y_new)
# Out:
# [[0]
#  [1]
#  [2]
#  [3]
#  [4]]
# [ 2.48367341 12.2594768  22.03528019 31.81108358 41.58688697]

# %% [markdown]
# **PLOTTING THE DATASET IN ALL POSSIBLE WAYS FOR BETTER UNDERSTANDING**

# %%
plt.scatter(x , y, color = "red")
plt.plot(x, model.predict(x), color = "green")
plt.title("Scores vs Hours (Training set)")
plt.xlabel("Hours of study")
plt.ylabel("Scores")
plt.show()

# %%
## setting plot style 
plt.style.use('fivethirtyeight') 
  
## plotting residual errors in training data 
plt.scatter(model.predict(x), model.predict(x) - y, 
            color = "green", s = 10, label = 'Train data') 
  
## plotting residual errors in test data 
plt.scatter(model.predict(x), model.predict(x) - y, 
            color = "blue", s = 10, label = 'Test data') 
  
## plotting line for zero residual error 
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 2) 
  
## plotting legend 
plt.legend(loc = 'upper right') 
  
## plot title 
plt.title("Residual errors") 
  
## function to show plot 
plt.show()

# %%
from sklearn.linear_model import LinearRegression
Regressor = LinearRegression()
Regressor.fit(x,y)
# Visualize the Data for Multiple Linear Regression
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure(figsize=(25,10))
### Set figure size
ax = fig.add_subplot(111, projection='3d')
ax.scatter(s_data['Hours'],s_data['Scores'],c='red', marker='o', alpha=0.5)
ax.plot_surface(x ,y, y_pred , color='b', alpha=0.3)
ax.set_xlabel('Hours')
ax.set_ylabel('Scores')
ax.set_zlabel('Adjusted')
plt.show()

# %%
sns.boxplot(x = 'Hours' , y = 'Scores' , data=s_data)

# %% [markdown]
# **DESCRIBING THE DATASET**

# %%
s_data.describe(include = 'all')
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# **SOME MORE VISUALIZATIONS**

# %%
sns.pairplot(s_data)

# %%
corr=s_data.corr()
corr
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %%
s_data.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fede81331d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fede8404518>]],
#       dtype=object)

# %%
sns.distplot(s_data['Hours'],bins=1)
sns.distplot(s_data['Scores'],bins=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.heatmap(corr , annot=True)

# %%
s_data.plot.bar() 

# plot between 2 attributes 
plt.bar(s_data['Hours'], s_data['Scores']) 
plt.xlabel("Hours") 
plt.ylabel("Scores") 
plt.show()

# %%
plt.pie(s_data['Hours'],autopct ='% 1.1f %%', shadow = True)  
plt.pie(s_data['Scores'],autopct ='% 1.1f %%', shadow = True)  
plt.show()

# %% [markdown]
# **PROOF OF THE DATASET TO BE A LINEAR DATASET**

# %%
sns.lmplot(x='Hours',y='Scores',data=s_data,legend=True,palette='red')

# %%
sns.countplot(x='Hours',data=s_data)
sns.countplot(x='Scores',data=s_data)
